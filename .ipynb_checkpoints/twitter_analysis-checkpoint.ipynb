# %%
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from matplotlib import style
style.use('ggplot')
import numpy as np

#from config import consumer_key,consumer_secret,access_token,access_token_secret
consumer_key='8nv71XPJ8vrW6VhYpHKEHlomW'
consumer_secret ='GvMuFKSVXYQDnBb6lJ5vmEQ2EWcQLPbdNafJZfYqjelid8mH4V'
access_token='930155118812696576-nzNCW8tnLfPIUbnos5Fbkss1flausez'
access_token_secret='CMk2BqwjW87i9tGbwktGk7P2KqdJ3QwjhadGiLS17o0am'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
user = "@BBC"
    # Variables for holding sentiments
sentiments1 = []
sentiments2= []
sentiments3=[]
sentiments4=[]
sentiments5=[]
    # Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments1.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
# Convert sentiments to DataFrame
sentiments1_pd = pd.DataFrame.from_dict(sentiments1)
bbc_mean=np.mean(sentiments1_pd['compound'])

sentiments1_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Nov 24 22:09:43 +0000 2017       0.0    0.735     0.265           1
# 1  Fri Nov 24 22:09:10 +0000 2017       0.0    1.000     0.000           2
# 2  Fri Nov 24 22:09:06 +0000 2017       0.0    0.864     0.136           3
# 3  Fri Nov 24 22:08:02 +0000 2017       0.0    0.753     0.247           4
# 4  Fri Nov 24 21:17:06 +0000 2017       0.0    0.856     0.144           5
#
#   Twitter_handle  compound
# 0           @BBC    0.6515
# 1           @BBC    0.0000
# 2           @BBC    0.5826
# 3           @BBC    0.5574
# 4           @BBC    0.4019

# %%
bbc_plot=plt.plot(sentiments1_pd['Tweets_ago'],sentiments1_pd['compound'], marker="o", 
               linewidth=0.25, alpha=0.8, color="lightskyblue",label='@BBC')
#plt.legend(bbc_plot,label=label,loc='best')
plt.show()

# %%
user="@CBS"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments2.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments2_pd = pd.DataFrame.from_dict(sentiments2)
cbs_mean=np.mean(sentiments2_pd['compound'])
sentiments2_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Sat Nov 25 00:43:31 +0000 2017       0.0    1.000     0.000           1
# 1  Fri Nov 24 23:37:02 +0000 2017       0.0    0.699     0.301           2
# 2  Fri Nov 24 15:00:03 +0000 2017       0.0    0.852     0.148           3
# 3  Fri Nov 24 14:56:13 +0000 2017       0.0    0.862     0.138           4
# 4  Fri Nov 24 13:57:14 +0000 2017       0.0    1.000     0.000           5
#
#   Twitter_handle  compound
# 0           @CBS    0.0000
# 1           @CBS    0.7845
# 2           @CBS    0.5400
# 3           @CBS    0.4926
# 4           @CBS    0.0000

# %%
user="@CNN"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments3.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments3_pd = pd.DataFrame.from_dict(sentiments3)
cnn_mean=np.mean(sentiments3_pd['compound'])
sentiments3_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Sat Nov 25 00:47:20 +0000 2017     0.169    0.688     0.144           1
# 1  Sat Nov 25 00:32:30 +0000 2017     0.000    0.865     0.135           2
# 2  Sat Nov 25 00:23:02 +0000 2017     0.000    1.000     0.000           3
# 3  Sat Nov 25 00:09:58 +0000 2017     0.048    0.847     0.105           4
# 4  Fri Nov 24 23:59:34 +0000 2017     0.000    1.000     0.000           5
#
#   Twitter_handle  compound
# 0           @CNN   -0.1027
# 1           @CNN    0.3612
# 2           @CNN    0.0000
# 3           @CNN    0.3400
# 4           @CNN    0.0000

# %%
user="@Fox"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments4.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments4_pd = pd.DataFrame.from_dict(sentiments4)
fox_mean=np.mean(sentiments4_pd['compound'])
sentiments4_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Nov 24 06:20:01 +0000 2017     0.114    0.782     0.104           1
# 1  Fri Nov 24 03:39:37 +0000 2017     0.000    0.421     0.579           2
# 2  Fri Nov 24 03:30:58 +0000 2017     0.000    1.000     0.000           3
# 3  Fri Nov 24 03:11:59 +0000 2017     0.094    0.730     0.176           4
# 4  Fri Nov 24 01:31:56 +0000 2017     0.000    0.147     0.853           5
#
#   Twitter_handle  compound
# 0           @Fox   -0.0772
# 1           @Fox    0.6696
# 2           @Fox    0.0000
# 3           @Fox    0.4404
# 4           @Fox    0.7003

# %%
user="@New York Times"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments5.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments5_pd = pd.DataFrame.from_dict(sentiments5)
nyt_mean=np.mean(sentiments5_pd['compound'])
sentiments5_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Nov 24 21:56:35 +0000 2017       0.0    0.616     0.384           1
# 1  Fri Nov 24 21:55:34 +0000 2017       0.0    0.616     0.384           2
# 2  Fri Nov 24 21:54:34 +0000 2017       0.0    0.616     0.384           3
# 3  Fri Nov 24 21:53:33 +0000 2017       0.0    0.616     0.384           4
# 4  Fri Nov 24 21:52:33 +0000 2017       0.0    0.616     0.384           5
#
#     Twitter_handle  compound
# 0  @New York Times    0.5204
# 1  @New York Times    0.5204
# 2  @New York Times    0.5204
# 3  @New York Times    0.5204
# 4  @New York Times    0.5204

# %%
plt.figure(figsize=(10,8))
plt.scatter(np.arange(len(sentiments1_pd["compound"])),
         sentiments1_pd["compound"], marker="o",s =200,facecolors="lightskyblue",linewidth=1,edgecolors='black',alpha=0.9,label="BBC")
plt.scatter(np.arange(len(sentiments2_pd["compound"])),
         sentiments2_pd["compound"], marker="o",s =200,facecolors="green",linewidth=1,edgecolors='black',alpha=0.9,label="CBS")
plt.scatter(np.arange(len(sentiments3_pd["compound"])),
         sentiments3_pd["compound"], marker="o",s =200,facecolors="red",linewidth=1,edgecolors='black',alpha=0.9,label="CNN")
plt.scatter(np.arange(len(sentiments4_pd["compound"])),
         sentiments4_pd["compound"], marker="o",s =200,facecolors="blue",linewidth=1,edgecolors='black',alpha=0.9,label="Fox")
plt.scatter(np.arange(len(sentiments5_pd["compound"])),
         sentiments5_pd["compound"], marker="o",s =200,facecolors="gold",linewidth=1,edgecolors='black',alpha=0.9,label="New York Times")



plt.ylim(-1,1)
plt.xlabel("Tweets ago")
plt.ylabel("Tweeet Polarity")
plt.title(f"Sentiment Analysis of Media Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
# Create a legend
lgnd = plt.legend(fontsize="medium",mode="Expanded",
                  numpoints=1, scatterpoints=1, bbox_to_anchor=(1, 1), shadow=True, ncol=1,
                  loc="best", title="Media Sources", 
                  labelspacing=0.5)
lgnd.legendHandles[0]._sizes = [70]
lgnd.legendHandles[1]._sizes = [70]
lgnd.legendHandles[2]._sizes = [70]
lgnd.legendHandles[3]._sizes = [70]
lgnd.legendHandles[4]._sizes = [70]
plt.show()

# %%
# bar plot visualising the overall sentiments of 100 tweets from each organisation
# create y and x axes for the bar chart
# calculating the average compound sentiments for each news organisation

y_axis=[bbc_mean,cbs_mean,cnn_mean,fox_mean,nyt_mean]
x_axis=np.arange(len(y_axis))

# %%
# make a bar plot
plt.figure(figsize=(10,8))
plt.bar(0,bbc_mean,color='lightskyblue',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(1,cbs_mean,color='green',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(2,cnn_mean,color='red',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(3,fox_mean,color='blue',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(4,nyt_mean,color='gold',align="edge",edgecolor='gray',width=1,alpha=0.8)
# Out:
# <Container object of 1 artists>

# %%
# placing the x-headers
tick_locations=[i+0.4  for i in x_axis]
plt.xticks(tick_locations,["BBC","CBS","CNN","Fox","NYT"],size="large")
# Out:
# ([<matplotlib.axis.XTick at 0x2ef31310438>,
#   <matplotlib.axis.XTick at 0x2ef308bf6d8>,
#   <matplotlib.axis.XTick at 0x2ef30728a20>,
#   <matplotlib.axis.XTick at 0x2ef307f2438>,
#   <matplotlib.axis.XTick at 0x2ef308c1940>],
#  <a list of 5 Text xticklabel objects>)

# %%
# x limits 
plt.xlim(0,len(x_axis))
# Out:
# (0, 5)

# %%
# y limits
plt.ylim(-0.5,0.6)
# Out:
# (-0.5, 0.6)

# %%
# setting axes labels and title
plt.title(f"Overall Media Sentiment based on Twitter ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.ylabel("Tweet Polarity")
plt.grid(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

plt.show()
