# %% [markdown]
# Observable Trends based On the data
# * CBSNews and CNN express negative sentiment in their recent 100 tweets and The New York Times expresses a close neutral sentiment possible.
# * Fox and BBCWorld express positive sentiment in their recent 100 tweets.
# * Fox news channel expresses that all is well in United States and BBCWorld reflects the overall growth and progression of the entire world.

# %%
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from matplotlib import style
style.use('ggplot')
import numpy as np

consumer_key='8nv71XPJ8vrW6VhYpHKEHlomW'
consumer_secret ='GvMuFKSVXYQDnBb6lJ5vmEQ2EWcQLPbdNafJZfYqjelid8mH4V'
access_token='930155118812696576-nzNCW8tnLfPIUbnos5Fbkss1flausez'
access_token_secret='CMk2BqwjW87i9tGbwktGk7P2KqdJ3QwjhadGiLS17o0am'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
user = "@BBC"
# Variables for holding sentiments
sentiments1=[]
sentiments2=[]
sentiments3=[]
sentiments4=[]
sentiments5=[]
# Counter
counter = 1

# Loop through recent 100 tweets for twitter handle @BBC
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments1.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1
        
sentiments1
# Out:
# [{'Date': 'Thu Feb 08 20:00:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.769,
#   'Positive': 0.231,
#   'Tweets_ago': 1,
#   'Twitter_handle': '@BBC',
#   'compound': 0.4019},
#  {'Date': 'Thu Feb 08 19:35:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.845,
#   'Positive': 0.155,
#   'Tweets_ago': 2,
#   'Twitter_handle': '@BBC',
#   'compound': 0.5106},
#  {'Date': 'Thu Feb 08 19:00:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.894,
#   'Positive': 0.106,
#   'Tweets_ago': 3,
#   'Twitter_handle': '@BBC',
#   'compound': 0.0772},
#  {'Date': 'Thu Feb 08 18:04:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 4,
#   'Twitter_handle': '@BBC',
#   'compound': 0.0},
#  {'Date': 'Thu Feb 08 17:31:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 5,
#   'Twitter_handle': '@BBC',
#   'compound': 0.0},
#  {'Date': 'Thu Feb 08 17:00:12 +0000 2018',
#   'Negative': 0.0,
# ...

# %%
# Convert sentiments to DataFrame
sentiments1_pd = pd.DataFrame.from_dict(sentiments1)

# Mean compound sentiment for recent 100 tweets of @BBC
bbc_mean=np.mean(sentiments1_pd['compound'])

sentiments1_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Feb 08 20:00:06 +0000 2018       0.0    0.769     0.231           1
# 1  Thu Feb 08 19:35:04 +0000 2018       0.0    0.845     0.155           2
# 2  Thu Feb 08 19:00:08 +0000 2018       0.0    0.894     0.106           3
# 3  Thu Feb 08 18:04:04 +0000 2018       0.0    1.000     0.000           4
# 4  Thu Feb 08 17:31:01 +0000 2018       0.0    1.000     0.000           5
#
#   Twitter_handle  compound
# 0           @BBC    0.4019
# 1           @BBC    0.5106
# 2           @BBC    0.0772
# 3           @BBC    0.0000
# 4           @BBC    0.0000

# %%
# write the dataframe into a csv file
sentiments1_pd.to_csv('bbcTweets.csv',header=True)

# %%
# line plot 
fig = plt.figure(figsize=(10,8))
bbc_plot=plt.plot(sentiments1_pd['Tweets_ago'],sentiments1_pd['compound'], marker="o", 
               linewidth=0.50, alpha=1,color='skyblue',label='@BBC')
plt.legend(handles=bbc_plot,bbox_to_anchor=(1.14,1),title="Tweets")
plt.title(f"Sentiment Analysis Of Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.savefig('BBC_Tweets.png',bbox_inches='tight')
plt.show()

# %%
user="@CBSNews"

# Counter
counter = 1

# Loop through 100 recent tweets of twitter handle @CBSNews
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments2.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1
sentiments2
# Out:
# [{'Date': 'Fri Feb 09 04:48:07 +0000 2018',
#   'Negative': 0.149,
#   'Neutral': 0.676,
#   'Positive': 0.176,
#   'Tweets_ago': 1,
#   'Twitter_handle': '@CBSNews',
#   'compound': 0.1027},
#  {'Date': 'Fri Feb 09 04:33:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 2,
#   'Twitter_handle': '@CBSNews',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:18:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 3,
#   'Twitter_handle': '@CBSNews',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:03:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.553,
#   'Positive': 0.447,
#   'Tweets_ago': 4,
#   'Twitter_handle': '@CBSNews',
#   'compound': 0.8658},
#  {'Date': 'Fri Feb 09 04:01:02 +0000 2018',
#   'Negative': 0.392,
#   'Neutral': 0.608,
#   'Positive': 0.0,
#   'Tweets_ago': 5,
#   'Twitter_handle': '@CBSNews',
#   'compound': -0.7964},
#  {'Date': 'Fri Feb 09 03:46:04 +0000 2018',
# ...

# %%
# creating dataframe for sentiments of tweets for @CBSNews
sentiments2_pd = pd.DataFrame.from_dict(sentiments2)

# Mean compound sentiment for @CBSNews
cbs_mean=np.mean(sentiments2_pd['compound'])

sentiments2_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Feb 09 04:48:07 +0000 2018     0.149    0.676     0.176           1
# 1  Fri Feb 09 04:33:06 +0000 2018     0.000    1.000     0.000           2
# 2  Fri Feb 09 04:18:11 +0000 2018     0.000    1.000     0.000           3
# 3  Fri Feb 09 04:03:08 +0000 2018     0.000    0.553     0.447           4
# 4  Fri Feb 09 04:01:02 +0000 2018     0.392    0.608     0.000           5
#
#   Twitter_handle  compound
# 0       @CBSNews    0.1027
# 1       @CBSNews    0.0000
# 2       @CBSNews    0.0000
# 3       @CBSNews    0.8658
# 4       @CBSNews   -0.7964

# %%
# write the dataframe into a csv file
sentiments2_pd.to_csv('CBS_Tweets.csv',header=True)

# %%
# Line plot
fig = plt.figure(figsize=(10,8))
cbs_plot=plt.plot(sentiments2_pd['Tweets_ago'],sentiments2_pd['compound'], marker="o", 
               linewidth=0.25, alpha=0.8, color="green",label='@CBSNews')
plt.legend(handles=cbs_plot,bbox_to_anchor=(1.2,1),title="Tweets")
plt.title(f"Sentiment Analysis Of Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.savefig('CBS_Tweets.png',bbox_inches='tight')
plt.show()

# %%
user="@CNN"

# Counter
counter = 1

# Loop through recent 100 tweets for @CNN
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments3.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1
sentiments3
# Out:
# [{'Date': 'Fri Feb 09 04:51:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 1,
#   'Twitter_handle': '@CNN',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:46:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 2,
#   'Twitter_handle': '@CNN',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:31:05 +0000 2018',
#   'Negative': 0.131,
#   'Neutral': 0.759,
#   'Positive': 0.11,
#   'Tweets_ago': 3,
#   'Twitter_handle': '@CNN',
#   'compound': -0.128},
#  {'Date': 'Fri Feb 09 04:16:04 +0000 2018',
#   'Negative': 0.306,
#   'Neutral': 0.694,
#   'Positive': 0.0,
#   'Tweets_ago': 4,
#   'Twitter_handle': '@CNN',
#   'compound': -0.765},
#  {'Date': 'Fri Feb 09 04:11:29 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.673,
#   'Positive': 0.327,
#   'Tweets_ago': 5,
#   'Twitter_handle': '@CNN',
#   'compound': 0.9042},
#  {'Date': 'Fri Feb 09 04:08:26 +0000 2018',
#   'Negative': 0.099,
# ...

# %%
# Creating Dtaframe for tweets for @CNN
sentiments3_pd = pd.DataFrame.from_dict(sentiments3)

# Mean compound sentiment for @CNN
cnn_mean=np.mean(sentiments3_pd['compound'])

sentiments3_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Feb 09 04:51:03 +0000 2018     0.000    1.000     0.000           1
# 1  Fri Feb 09 04:46:04 +0000 2018     0.000    1.000     0.000           2
# 2  Fri Feb 09 04:31:05 +0000 2018     0.131    0.759     0.110           3
# 3  Fri Feb 09 04:16:04 +0000 2018     0.306    0.694     0.000           4
# 4  Fri Feb 09 04:11:29 +0000 2018     0.000    0.673     0.327           5
#
#   Twitter_handle  compound
# 0           @CNN    0.0000
# 1           @CNN    0.0000
# 2           @CNN   -0.1280
# 3           @CNN   -0.7650
# 4           @CNN    0.9042

# %%
# write the dataframe into a csv file
sentiments3_pd.to_csv('CNN_Tweets.csv',header=True)

# %%
# Line plot
fig = plt.figure(figsize=(10,8))
cnn_plot=plt.plot(sentiments3_pd['Tweets_ago'],sentiments3_pd['compound'], marker="o", 
               linewidth=0.25, alpha=0.8, color="red",label='@CNN')
plt.legend(handles=cnn_plot,bbox_to_anchor=(1.14,1),title="Tweets")
plt.title(f"Sentiment Analysis Of Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.savefig('CNN_Tweets.png',bbox_inches='tight')
plt.show()

# %%
user="@Fox"

# Counter
counter = 1

# Loop through recent 100 tweets for @Fox
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments4.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

sentiments4
# Out:
# [{'Date': 'Fri Feb 09 03:29:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.821,
#   'Positive': 0.179,
#   'Tweets_ago': 1,
#   'Twitter_handle': '@Fox',
#   'compound': 0.4451},
#  {'Date': 'Fri Feb 09 01:59:17 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 2,
#   'Twitter_handle': '@Fox',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 01:45:27 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Tweets_ago': 3,
#   'Twitter_handle': '@Fox',
#   'compound': 0.128},
#  {'Date': 'Fri Feb 09 01:29:08 +0000 2018',
#   'Negative': 0.216,
#   'Neutral': 0.784,
#   'Positive': 0.0,
#   'Tweets_ago': 4,
#   'Twitter_handle': '@Fox',
#   'compound': -0.5106},
#  {'Date': 'Fri Feb 09 01:16:03 +0000 2018',
#   'Negative': 0.129,
#   'Neutral': 0.706,
#   'Positive': 0.165,
#   'Tweets_ago': 5,
#   'Twitter_handle': '@Fox',
#   'compound': 0.2263},
#  {'Date': 'Fri Feb 09 01:14:30 +0000 2018',
# ...

# %%
# Create dataframe for sentiments of tweets for @Fox
sentiments4_pd = pd.DataFrame.from_dict(sentiments4)

# Mean compound sentiment for @Fox
fox_mean=np.mean(sentiments4_pd['compound'])

sentiments4_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Feb 09 03:29:31 +0000 2018     0.000    0.821     0.179           1
# 1  Fri Feb 09 01:59:17 +0000 2018     0.000    1.000     0.000           2
# 2  Fri Feb 09 01:45:27 +0000 2018     0.000    0.923     0.077           3
# 3  Fri Feb 09 01:29:08 +0000 2018     0.216    0.784     0.000           4
# 4  Fri Feb 09 01:16:03 +0000 2018     0.129    0.706     0.165           5
#
#   Twitter_handle  compound
# 0           @Fox    0.4451
# 1           @Fox    0.0000
# 2           @Fox    0.1280
# 3           @Fox   -0.5106
# 4           @Fox    0.2263

# %%
# write the dataframe into a csv file
sentiments4_pd.to_csv('Fox_Tweets.csv',header=True)

# %%
#Line plot
fig = plt.figure(figsize=(10,8))
fox_plot=plt.plot(sentiments4_pd['Tweets_ago'],sentiments4_pd['compound'], marker="o", 
               linewidth=0.25, alpha=0.8, color="blue",label='@Fox')
plt.legend(handles=fox_plot,bbox_to_anchor=(1.13,1),title="Tweets")
plt.title(f"Sentiment Analysis Of Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.savefig('Fox_Tweets.png',bbox_inches='tight')
plt.show()

# %%
user="@nytimes"

# Counter
counter = 1
# Loop through recent 100 tweets for @nytimes
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments5.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1
sentiments5
# Out:
# [{'Date': 'Fri Feb 09 04:48:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 1,
#   'Twitter_handle': '@nytimes',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:33:02 +0000 2018',
#   'Negative': 0.239,
#   'Neutral': 0.761,
#   'Positive': 0.0,
#   'Tweets_ago': 2,
#   'Twitter_handle': '@nytimes',
#   'compound': -0.296},
#  {'Date': 'Fri Feb 09 04:14:23 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 3,
#   'Twitter_handle': '@nytimes',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 04:00:41 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweets_ago': 4,
#   'Twitter_handle': '@nytimes',
#   'compound': 0.0},
#  {'Date': 'Fri Feb 09 03:52:05 +0000 2018',
#   'Negative': 0.103,
#   'Neutral': 0.851,
#   'Positive': 0.046,
#   'Tweets_ago': 5,
#   'Twitter_handle': '@nytimes',
#   'compound': -0.3818},
#  {'Date': 'Fri Feb 09 03:48:01 +0000 2018',
# ...

# %%
# create Dataframe for sentiments of tweets for @nytimes
sentiments5_pd = pd.DataFrame.from_dict(sentiments5)

# Mean compound sentiment for @nytimes
nyt_mean=np.mean(sentiments5_pd['compound'])

sentiments5_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Fri Feb 09 04:48:05 +0000 2018     0.000    1.000     0.000           1
# 1  Fri Feb 09 04:33:02 +0000 2018     0.239    0.761     0.000           2
# 2  Fri Feb 09 04:14:23 +0000 2018     0.000    1.000     0.000           3
# 3  Fri Feb 09 04:00:41 +0000 2018     0.000    1.000     0.000           4
# 4  Fri Feb 09 03:52:05 +0000 2018     0.103    0.851     0.046           5
#
#   Twitter_handle  compound
# 0       @nytimes    0.0000
# 1       @nytimes   -0.2960
# 2       @nytimes    0.0000
# 3       @nytimes    0.0000
# 4       @nytimes   -0.3818

# %%
# write the dataframe into a csv file
sentiments5_pd.to_csv('NYT_Tweets.csv',header=True)

# %%
#line plot
fig = plt.figure(figsize=(10,8))
nyt_plot=plt.plot(sentiments5_pd['Tweets_ago'],sentiments5_pd['compound'], marker="o", 
               linewidth=0.50, alpha=1, color="gold",label='@nytimes')
plt.legend(handles=nyt_plot,bbox_to_anchor=(1.18,1),title="Tweets")
plt.title(f"Sentiment Analysis Of Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.savefig('NYT_Tweets.png',bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(np.arange(len(sentiments1_pd["compound"])),
         sentiments1_pd["compound"], marker="o",s =200,facecolors="lightskyblue",linewidth=1,edgecolors='black',alpha=0.9,label="@BBCWorld")
plt.scatter(np.arange(len(sentiments2_pd["compound"])),
         sentiments2_pd["compound"], marker="o",s =200,facecolors="green",linewidth=1,edgecolors='black',alpha=0.9,label="@CBSNews")
plt.scatter(np.arange(len(sentiments3_pd["compound"])),
         sentiments3_pd["compound"], marker="o",s =200,facecolors="red",linewidth=1,edgecolors='black',alpha=0.9,label="@CNN")
plt.scatter(np.arange(len(sentiments4_pd["compound"])),
         sentiments4_pd["compound"], marker="o",s =200,facecolors="blue",linewidth=1,edgecolors='black',alpha=0.9,label="@FoxNews")
plt.scatter(np.arange(len(sentiments5_pd["compound"])),
         sentiments5_pd["compound"], marker="o",s =200,facecolors="gold",linewidth=1,edgecolors='black',alpha=0.9,label="@nytimes")



plt.ylim(-1,1)
plt.xlabel("Tweets ago")
plt.ylabel("Tweeet Polarity")
plt.title(f"Sentiment Analysis of Media Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
# Create a legend
lgnd = plt.legend(fontsize="medium",mode="Expanded",
                  numpoints=1, scatterpoints=1, bbox_to_anchor=(1, 1), shadow=True, ncol=1,
                  loc="best", title="Media Sources", 
                  labelspacing=0.5)
lgnd.legendHandles[0]._sizes = [70]
lgnd.legendHandles[1]._sizes = [70]
lgnd.legendHandles[2]._sizes = [70]
lgnd.legendHandles[3]._sizes = [70]
lgnd.legendHandles[4]._sizes = [70]
plt.savefig('Media_Tweets.png',bbox_inches='tight')
plt.show()

# %%
# bar plot visualising the overall sentiments of 100 tweets from each organisation
# create y and x axes for the bar chart
# calculating the average compound sentiments for each news organisation

y_axis=[bbc_mean,cbs_mean,cnn_mean,fox_mean,nyt_mean]
x_axis=np.arange(len(y_axis))

# %%
# make a bar plot
plt.figure(figsize=(10,8))
plt.bar(0,bbc_mean,color='lightskyblue',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(1,cbs_mean,color='green',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(2,cnn_mean,color='red',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(3,fox_mean,color='blue',align="edge",edgecolor='gray',width=1,alpha=0.8)
plt.bar(4,nyt_mean,color='gold',align="edge",edgecolor='gray',width=1,alpha=0.8)
# Out:
# <Container object of 1 artists>

# %%
# placing the x-headers
tick_locations=[i+0.4  for i in x_axis]
plt.xticks(tick_locations,["BBC","CBS","CNN","Fox","NYT"],size="large")
# Out:
# ([<matplotlib.axis.XTick at 0x2d9c981f908>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
# x limits 
plt.xlim(0,len(x_axis))
# Out:
# (0, 5)

# %%
# y limits
plt.ylim(-0.5,0.6)
# Out:
# (-0.5, 0.6)

# %%
# setting axes labels and title
plt.title(f"Overall Media Sentiment based on Twitter ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
plt.ylabel("Tweet Polarity")
plt.grid(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.savefig("Media_Sentiments.png",bbox_inches='tight')

plt.show()
