# %%
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from matplotlib import style
style.use('ggplot')
import numpy as np

#from config import consumer_key,consumer_secret,access_token,access_token_secret
consumer_key='8nv71XPJ8vrW6VhYpHKEHlomW'
consumer_secret ='GvMuFKSVXYQDnBb6lJ5vmEQ2EWcQLPbdNafJZfYqjelid8mH4V'
access_token='930155118812696576-nzNCW8tnLfPIUbnos5Fbkss1flausez'
access_token_secret='CMk2BqwjW87i9tGbwktGk7P2KqdJ3QwjhadGiLS17o0am'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
target_user = ["@BBC"]#"@CBS"]
#,"@CNN","@Fox","@New York Times"]

    # Variables for holding sentiments
    sentiments1 = []
    sentiments2= []
    sentiments3=[]
    sentiments4=[]
    sentiments5=[]
    # Counter
    counter = 1
    for x in range(5):
        public_tweets = api.user_timeline(user,page=x)
        for tweet in public_tweets:
            results = analyzer.polarity_scores(tweet["text"])
            compound = results['compound']
            pos = results['pos']
            neg = results['neg']
            neu = results['neu']
            
                sentiments1.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
                counter=counter+1

# %%
# Convert sentiments to DataFrame
sentiments1_pd = pd.DataFrame.from_dict(sentiments1)
sentiments1_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Nov 23 15:03:01 +0000 2017     0.000    1.000     0.000           1
# 1  Thu Nov 23 14:52:25 +0000 2017     0.000    1.000     0.000           2
# 2  Thu Nov 23 14:51:08 +0000 2017     0.209    0.791     0.000           3
# 3  Thu Nov 23 14:50:07 +0000 2017     0.000    0.697     0.303           4
# 4  Thu Nov 23 14:49:49 +0000 2017     0.133    0.867     0.000           5
#
#   Twitter_handle  compound
# 0           @BBC    0.0000
# 1           @BBC    0.0000
# 2           @BBC   -0.6705
# 3           @BBC    0.7263
# 4           @BBC   -0.1566

# %%
user="@CBS"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments2.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments2_pd = pd.DataFrame.from_dict(sentiments2)
sentiments2_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Nov 23 15:07:33 +0000 2017       0.0    0.765     0.235           1
# 1  Wed Nov 22 23:08:26 +0000 2017       0.0    1.000     0.000           2
# 2  Wed Nov 22 22:45:04 +0000 2017       0.0    0.760     0.240           3
# 3  Wed Nov 22 21:18:51 +0000 2017       0.0    1.000     0.000           4
# 4  Wed Nov 22 20:44:16 +0000 2017       0.0    1.000     0.000           5
#
#   Twitter_handle  compound
# 0           @CBS    0.6114
# 1           @CBS    0.0000
# 2           @CBS    0.6900
# 3           @CBS    0.0000
# 4           @CBS    0.0000

# %%
user="@CNN"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments3.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments3_pd = pd.DataFrame.from_dict(sentiments3)
sentiments3_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Nov 23 15:30:07 +0000 2017     0.115    0.885     0.000           1
# 1  Thu Nov 23 15:20:58 +0000 2017     0.000    1.000     0.000           2
# 2  Thu Nov 23 15:10:05 +0000 2017     0.000    0.750     0.250           3
# 3  Thu Nov 23 15:00:13 +0000 2017     0.000    1.000     0.000           4
# 4  Thu Nov 23 14:50:05 +0000 2017     0.202    0.673     0.126           5
#
#   Twitter_handle  compound
# 0           @CNN   -0.2960
# 1           @CNN    0.0000
# 2           @CNN    0.7184
# 3           @CNN    0.0000
# 4           @CNN   -0.1779

# %%
user="@Fox"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments4.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments4_pd = pd.DataFrame.from_dict(sentiments4)
sentiments4_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Nov 23 09:48:49 +0000 2017       0.0    0.901     0.099           1
# 1  Thu Nov 23 07:02:44 +0000 2017       0.0    1.000     0.000           2
# 2  Thu Nov 23 00:49:58 +0000 2017       0.0    1.000     0.000           3
# 3  Thu Nov 23 00:36:42 +0000 2017       0.0    0.783     0.217           4
# 4  Wed Nov 22 22:02:09 +0000 2017       0.0    0.435     0.565           5
#
#   Twitter_handle  compound
# 0           @Fox    0.2716
# 1           @Fox    0.0000
# 2           @Fox    0.0000
# 3           @Fox    0.5574
# 4           @Fox    0.5994

# %%
user="@New York Times"
# Counter
counter = 1
for x in range(5):
    public_tweets = api.user_timeline(user,page=x)
    for tweet in public_tweets:
        results = analyzer.polarity_scores(tweet["text"])
        compound = results['compound']
        pos = results['pos']
        neg = results['neg']
        neu = results['neu']
            
        sentiments5.append({"Twitter_handle":user,"Date":tweet["created_at"],
                               "compound":compound,
                               "Positive":pos,
                               "Negative":neg,
                               "Neutral":neu,
                               "Tweets_ago":counter})
        counter=counter+1

# %%
sentiments5_pd = pd.DataFrame.from_dict(sentiments5)
sentiments5_pd.head()
# Out:
#                              Date  Negative  Neutral  Positive  Tweets_ago  \
# 0  Thu Nov 23 09:06:01 +0000 2017       0.0    0.616     0.384           1
# 1  Thu Nov 23 09:05:01 +0000 2017       0.0    0.616     0.384           2
# 2  Thu Nov 23 09:04:00 +0000 2017       0.0    0.616     0.384           3
# 3  Thu Nov 23 09:03:00 +0000 2017       0.0    0.616     0.384           4
# 4  Thu Nov 23 09:02:00 +0000 2017       0.0    0.616     0.384           5
#
#     Twitter_handle  compound
# 0  @New York Times    0.5204
# 1  @New York Times    0.5204
# 2  @New York Times    0.5204
# 3  @New York Times    0.5204
# 4  @New York Times    0.5204

# %%
plt.figure(figsize=(10,8))
plt.scatter(np.arange(len(sentiments1_pd["compound"])),
         sentiments1_pd["compound"], marker="o",s =200,facecolors="lightskyblue",linewidth=1,edgecolors='black',alpha=0.9,label="BBC")
plt.scatter(np.arange(len(sentiments2_pd["compound"])),
         sentiments2_pd["compound"], marker="o",s =200,facecolors="green",linewidth=1,edgecolors='black',alpha=0.9,label="CBS")
plt.scatter(np.arange(len(sentiments3_pd["compound"])),
         sentiments3_pd["compound"], marker="o",s =200,facecolors="red",linewidth=1,edgecolors='black',alpha=0.9,label="CNN")
plt.scatter(np.arange(len(sentiments4_pd["compound"])),
         sentiments4_pd["compound"], marker="o",s =200,facecolors="blue",linewidth=1,edgecolors='black',alpha=0.9,label="Fox")
plt.scatter(np.arange(len(sentiments5_pd["compound"])),
         sentiments5_pd["compound"], marker="o",s =200,facecolors="gold",linewidth=1,edgecolors='black',alpha=0.9,label="New York Times")



plt.ylim(-1,1)
plt.xlabel("Tweets ago")
plt.ylabel("Tweeet Polarity")
plt.title(f"Sentiment Analysis of Media Tweets ({datetime.now().strftime('%Y-%m-%d %H:%M')})")
# Create a legend
lgnd = plt.legend(fontsize="medium",mode="Expanded",
                  numpoints=1, scatterpoints=1, bbox_to_anchor=(1, 1), shadow=True, ncol=1,
                  loc="best", title="Media Sources", 
                  labelspacing=0.5)
lgnd.legendHandles[0]._sizes = [70]
lgnd.legendHandles[1]._sizes = [70]
lgnd.legendHandles[2]._sizes = [70]
lgnd.legendHandles[3]._sizes = [70]
lgnd.legendHandles[4]._sizes = [70]
plt.show()

# %%
# bar plot visualising the overall sentiments of 100 tweets from each organisation
